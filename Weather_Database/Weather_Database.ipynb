# %%
# import dependencies
import pandas as pd
import requests
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
from datetime import datetime
# import the time module
import time
# import the API key
from config import weather_api_key

# %%
# create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
# create a list to hold the cities
cities = []

# identify the nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # if the city is unique, add it to cities[]
    if city not in cities:
        cities.append(city)

# %%
# starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# create an empty list to hold the weather data
city_data = []

# print the beginning of the logging.
print("Beginning Data Retrieval")
print("-----------------------------")

# create counters
record_count = 1
set_count = 1

# loop through all the cities
for i, city in enumerate(cities):
    
    # group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >=50):
        set_count += 1
        record_count = 1
        
    # create endpoint url with each city
    city_url = url + "&q=" + city#.replace(" ", "+")
    
    # log the url, record and set numbers and the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    #increase record count
    record_count += 1
    
    # run an API request for each of the cities.
    # parse the JSON and retrieve data
    try:
        # parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        # parse out the needed data
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_description = city_weather['weather'][0]['description']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        # convert the date to iso standard
        city_date = datetime.utcfromtimestamp(city_weather['dt']).strftime('%Y-%m-%d %H:%M:%S')
        # Append city information into city_data list.
        city_data.append({"City": city.title(), "Lat": city_lat, "Lng": city_lng, "Max Temp": city_max_temp, \
                         "Humidity": city_humidity, "Cloudiness": city_clouds, "Wind Speed": city_wind, \
                         "Description": city_description, "Country": city_country, "Date": city_date})
        # if an error occurs, skip city
    except:
        print("City not found. Skipping. . .")
        pass
    
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | yar-sale
# Processing Record 2 of Set 1 | kozhva
# Processing Record 3 of Set 1 | basco
# Processing Record 4 of Set 1 | laje
# Processing Record 5 of Set 1 | dubasari
# Processing Record 6 of Set 1 | muros
# Processing Record 7 of Set 1 | port hardy
# Processing Record 8 of Set 1 | chalmette
# Processing Record 9 of Set 1 | bluff
# Processing Record 10 of Set 1 | punta arenas
# Processing Record 11 of Set 1 | husavik
# Processing Record 12 of Set 1 | new norfolk
# Processing Record 13 of Set 1 | bodden town
# Processing Record 14 of Set 1 | port blair
# Processing Record 15 of Set 1 | ahipara
# Processing Record 16 of Set 1 | lebu
# Processing Record 17 of Set 1 | coahuayana
# Processing Record 18 of Set 1 | jamestown
# Processing Record 19 of Set 1 | bredasdorp
# Processing Record 20 of Set 1 | santiago
# Processing Record 21 of Set 1 | albany
# Processing Record 22 of Set 1 | cambyreta
# City not found. Skipping. . .
# Processing Record 23 of Set 1 | vaini
# Processing Record 24 of Set 1 | sembakung
# Processing Record 25 of Set 1 | lagoa
# Processing Record 26 of Set 1 | busselton
# Processing Record 27 of Set 1 | rawson
# Processing Record 28 of Set 1 | ushuaia
# Processing Record 29 of Set 1 | tshikapa
# Processing Record 30 of Set 1 | avarua
# Processing Record 31 of Set 1 | magadan
# Processing Record 32 of Set 1 | katihar
# Processing Record 33 of Set 1 | cherskiy
# Processing Record 34 of Set 1 | rikitea
# Processing Record 35 of Set 1 | upernavik
# Processing Record 36 of Set 1 | poum
# Processing Record 37 of Set 1 | clyde river
# Processing Record 38 of Set 1 | kencong
# Processing Record 39 of Set 1 | mataura
# Processing Record 40 of Set 1 | coquimbo
# Processing Record 41 of Set 1 | amderma
# City not found. Skipping. . .
# Processing Record 42 of Set 1 | opuwo
# Processing Record 43 of Set 1 | saquisili
# Processing Record 44 of Set 1 | khatanga
# Processing Record 45 of Set 1 | mahebourg
# Processing Record 46 of Set 1 | baraboo
# Processing Record 47 of Set 1 | kahului
# Processing Record 48 of Set 1 | kimry
# Processing Record 49 of Set 1 | hilo
# Processing Record 50 of Set 1 | vila franca do campo
# Processing Record 1 of Set 2 | bethel
# Processing Record 2 of Set 2 | butaritari
# Processing Record 3 of Set 2 | yeppoon
# Processing Record 4 of Set 2 | sitka
# Processing Record 5 of Set 2 | belaya gora
# Processing Record 6 of Set 2 | taolanaro
# City not found. Skipping. . .
# Processing Record 7 of Set 2 | dzhusaly
# City not found. Skipping. . .
# Processing Record 8 of Set 2 | barentsburg
# City not found. Skipping. . .
# Processing Record 9 of Set 2 | illoqqortoormiut
# City not found. Skipping. . .
# Processing Record 10 of Set 2 | mangotsfield
# Processing Record 11 of Set 2 | kushima
# Processing Record 12 of Set 2 | chokurdakh
# Processing Record 13 of Set 2 | sorland
# Processing Record 14 of Set 2 | carnarvon
# Processing Record 15 of Set 2 | scottsburgh
# City not found. Skipping. . .
# Processing Record 16 of Set 2 | nizhneyansk
# City not found. Skipping. . .
# Processing Record 17 of Set 2 | atuona
# Processing Record 18 of Set 2 | westport
# Processing Record 19 of Set 2 | elko
# Processing Record 20 of Set 2 | bargal
# City not found. Skipping. . .
# Processing Record 21 of Set 2 | pingliang
# Processing Record 22 of Set 2 | sao geraldo do araguaia
# Processing Record 23 of Set 2 | amapa
# Processing Record 24 of Set 2 | fevralsk
# City not found. Skipping. . .
# Processing Record 25 of Set 2 | qaanaaq
# Processing Record 26 of Set 2 | dikson
# Processing Record 27 of Set 2 | leh
# Processing Record 28 of Set 2 | kodiak
# Processing Record 29 of Set 2 | east london
# Processing Record 30 of Set 2 | adre
# Processing Record 31 of Set 2 | barrow
# Processing Record 32 of Set 2 | lyubinskiy
# Processing Record 33 of Set 2 | oyama
# Processing Record 34 of Set 2 | grand gaube
# Processing Record 35 of Set 2 | oriximina
# Processing Record 36 of Set 2 | cape town
# Processing Record 37 of Set 2 | pandan
# Processing Record 38 of Set 2 | port alfred
# Processing Record 39 of Set 2 | biltine
# Processing Record 40 of Set 2 | ozernovskiy
# Processing Record 41 of Set 2 | north bend
# Processing Record 42 of Set 2 | castro
# Processing Record 43 of Set 2 | vaitupu
# City not found. Skipping. . .
# Processing Record 44 of Set 2 | hithadhoo
# Processing Record 45 of Set 2 | srednekolymsk
# Processing Record 46 of Set 2 | makakilo city
# Processing Record 47 of Set 2 | black river
# Processing Record 48 of Set 2 | pevek
# Processing Record 49 of Set 2 | parainen
# Processing Record 50 of Set 2 | bairiki
# Processing Record 1 of Set 3 | fiche
# Processing Record 2 of Set 3 | saint-philippe
# Processing Record 3 of Set 3 | kaitangata
# Processing Record 4 of Set 3 | isangel
# Processing Record 5 of Set 3 | victor harbor
# Processing Record 6 of Set 3 | hermanus
# Processing Record 7 of Set 3 | tuatapere
# Processing Record 8 of Set 3 | quatre cocos
# Processing Record 9 of Set 3 | thompson
# Processing Record 10 of Set 3 | zhongshu
# Processing Record 11 of Set 3 | krasnoselkup
# Processing Record 12 of Set 3 | fukue
# Processing Record 13 of Set 3 | mangrol
# Processing Record 14 of Set 3 | yellowknife
# Processing Record 15 of Set 3 | palabuhanratu
# City not found. Skipping. . .
# Processing Record 16 of Set 3 | narsaq
# Processing Record 17 of Set 3 | hovd
# Processing Record 18 of Set 3 | yanji
# Processing Record 19 of Set 3 | camacha
# Processing Record 20 of Set 3 | nouadhibou
# Processing Record 21 of Set 3 | yarada
# Processing Record 22 of Set 3 | belushya guba
# City not found. Skipping. . .
# Processing Record 23 of Set 3 | a
# City not found. Skipping. . .
# Processing Record 24 of Set 3 | sao filipe
# Processing Record 25 of Set 3 | boguchany
# Processing Record 26 of Set 3 | praia da vitoria
# Processing Record 27 of Set 3 | beringovskiy
# Processing Record 28 of Set 3 | sentyabrskiy
# City not found. Skipping. . .
# Processing Record 29 of Set 3 | vestmannaeyjar
# Processing Record 30 of Set 3 | oktyabrskiy
# Processing Record 31 of Set 3 | sembe
# Processing Record 32 of Set 3 | zakamensk
# Processing Record 33 of Set 3 | kuttanallur
# City not found. Skipping. . .
# Processing Record 34 of Set 3 | boende
# Processing Record 35 of Set 3 | nemuro
# Processing Record 36 of Set 3 | cidreira
# Processing Record 37 of Set 3 | piopio
# Processing Record 38 of Set 3 | tasiilaq
# Processing Record 39 of Set 3 | sao joao da barra
# Processing Record 40 of Set 3 | provideniya
# Processing Record 41 of Set 3 | chuy
# Processing Record 42 of Set 3 | tuktoyaktuk
# Processing Record 43 of Set 3 | rajakhera
# Processing Record 44 of Set 3 | kabo
# Processing Record 45 of Set 3 | port elizabeth
# Processing Record 46 of Set 3 | kapaa
# Processing Record 47 of Set 3 | tukrah
# Processing Record 48 of Set 3 | kirakira
# Processing Record 49 of Set 3 | sucre
# Processing Record 50 of Set 3 | sloboda
# Processing Record 1 of Set 4 | pandharpur
# Processing Record 2 of Set 4 | gusau
# Processing Record 3 of Set 4 | te anau
# Processing Record 4 of Set 4 | mehamn
# Processing Record 5 of Set 4 | geraldton
# Processing Record 6 of Set 4 | mabaruma
# Processing Record 7 of Set 4 | san joaquin
# Processing Record 8 of Set 4 | anadyr
# Processing Record 9 of Set 4 | tiksi
# Processing Record 10 of Set 4 | hobart
# Processing Record 11 of Set 4 | kilindoni
# Processing Record 12 of Set 4 | smolenka
# Processing Record 13 of Set 4 | vitimskiy
# City not found. Skipping. . .
# Processing Record 14 of Set 4 | grand river south east
# City not found. Skipping. . .
# Processing Record 15 of Set 4 | yulara
# Processing Record 16 of Set 4 | nome
# Processing Record 17 of Set 4 | eureka
# Processing Record 18 of Set 4 | arraial do cabo
# Processing Record 19 of Set 4 | aden
# Processing Record 20 of Set 4 | bur gabo
# City not found. Skipping. . .
# Processing Record 21 of Set 4 | esperance
# Processing Record 22 of Set 4 | laguna
# Processing Record 23 of Set 4 | tambacounda
# Processing Record 24 of Set 4 | kalmunai
# Processing Record 25 of Set 4 | karasjok
# Processing Record 26 of Set 4 | dharchula
# Processing Record 27 of Set 4 | mar del plata
# Processing Record 28 of Set 4 | puerto penasco
# Processing Record 29 of Set 4 | vila
# Processing Record 30 of Set 4 | santa maria
# Processing Record 31 of Set 4 | olafsvik
# Processing Record 32 of Set 4 | severo-kurilsk
# Processing Record 33 of Set 4 | lyngseidet
# Processing Record 34 of Set 4 | shimoda
# Processing Record 35 of Set 4 | flin flon
# Processing Record 36 of Set 4 | meulaboh
# Processing Record 37 of Set 4 | puerto ayora
# Processing Record 38 of Set 4 | keetmanshoop
# Processing Record 39 of Set 4 | chesterton
# Processing Record 40 of Set 4 | sawtell
# Processing Record 41 of Set 4 | sabang
# Processing Record 42 of Set 4 | perbaungan
# Processing Record 43 of Set 4 | kununurra
# Processing Record 44 of Set 4 | boa vista
# Processing Record 45 of Set 4 | calama
# Processing Record 46 of Set 4 | gewane
# Processing Record 47 of Set 4 | kintinku
# Processing Record 48 of Set 4 | pisco
# Processing Record 49 of Set 4 | tabiauea
# City not found. Skipping. . .
# Processing Record 50 of Set 4 | bratsk
# Processing Record 1 of Set 5 | cabedelo
# Processing Record 2 of Set 5 | batagay-alyta
# Processing Record 3 of Set 5 | ostrovnoy
# Processing Record 4 of Set 5 | chumikan
# Processing Record 5 of Set 5 | saldanha
# Processing Record 6 of Set 5 | cabinda
# Processing Record 7 of Set 5 | puerto quijarro
# Processing Record 8 of Set 5 | luderitz
# Processing Record 9 of Set 5 | mount gambier
# Processing Record 10 of Set 5 | kavaratti
# Processing Record 11 of Set 5 | baie-comeau
# Processing Record 12 of Set 5 | saint-leu
# Processing Record 13 of Set 5 | bjornevatn
# Processing Record 14 of Set 5 | matadi
# Processing Record 15 of Set 5 | ribeira grande
# Processing Record 16 of Set 5 | buraydah
# Processing Record 17 of Set 5 | barbar
# City not found. Skipping. . .
# Processing Record 18 of Set 5 | stornoway
# Processing Record 19 of Set 5 | cabo san lucas
# Processing Record 20 of Set 5 | qalyub
# Processing Record 21 of Set 5 | valparaiso
# Processing Record 22 of Set 5 | bambous virieux
# Processing Record 23 of Set 5 | georgetown
# Processing Record 24 of Set 5 | half moon bay
# Processing Record 25 of Set 5 | kuche
# City not found. Skipping. . .
# Processing Record 26 of Set 5 | itaituba
# Processing Record 27 of Set 5 | pampas
# Processing Record 28 of Set 5 | atlantic beach
# Processing Record 29 of Set 5 | ramhormoz
# Processing Record 30 of Set 5 | norman wells
# Processing Record 31 of Set 5 | aksu
# Processing Record 32 of Set 5 | shchelyayur
# City not found. Skipping. . .
# Processing Record 33 of Set 5 | broome
# Processing Record 34 of Set 5 | dakar
# Processing Record 35 of Set 5 | stettler
# Processing Record 36 of Set 5 | saint george
# Processing Record 37 of Set 5 | panguipulli
# Processing Record 38 of Set 5 | fairbanks
# Processing Record 39 of Set 5 | ilulissat
# Processing Record 40 of Set 5 | lahij
# Processing Record 41 of Set 5 | la asuncion
# Processing Record 42 of Set 5 | san ramon
# Processing Record 43 of Set 5 | teknaf
# Processing Record 44 of Set 5 | tessalit
# Processing Record 45 of Set 5 | atascocita
# Processing Record 46 of Set 5 | chunskiy
# Processing Record 47 of Set 5 | kathu
# Processing Record 48 of Set 5 | manhattan
# Processing Record 49 of Set 5 | zhangjiakou
# Processing Record 50 of Set 5 | montepuez
# Processing Record 1 of Set 6 | san policarpo
# Processing Record 2 of Set 6 | samalaeulu
# City not found. Skipping. . .
# Processing Record 3 of Set 6 | nelson bay
# Processing Record 4 of Set 6 | kavieng
# Processing Record 5 of Set 6 | tupik
# Processing Record 6 of Set 6 | bambanglipuro
# Processing Record 7 of Set 6 | saint-augustin
# Processing Record 8 of Set 6 | taltal
# Processing Record 9 of Set 6 | vyazemskiy
# Processing Record 10 of Set 6 | harper
# Processing Record 11 of Set 6 | terrace bay
# Processing Record 12 of Set 6 | heihe
# Processing Record 13 of Set 6 | tungkang
# City not found. Skipping. . .
# Processing Record 14 of Set 6 | inta
# Processing Record 15 of Set 6 | aklavik
# Processing Record 16 of Set 6 | malwan
# City not found. Skipping. . .
# Processing Record 17 of Set 6 | sao felix do xingu
# Processing Record 18 of Set 6 | mtimbira
# Processing Record 19 of Set 6 | manono
# Processing Record 20 of Set 6 | bilma
# Processing Record 21 of Set 6 | nikolskoye
# Processing Record 22 of Set 6 | katsuura
# Processing Record 23 of Set 6 | pontes e lacerda
# Processing Record 24 of Set 6 | charters towers
# Processing Record 25 of Set 6 | vila velha
# Processing Record 26 of Set 6 | hofn
# Processing Record 27 of Set 6 | attawapiskat
# City not found. Skipping. . .
# Processing Record 28 of Set 6 | prince albert
# Processing Record 29 of Set 6 | placido de castro
# Processing Record 30 of Set 6 | ulladulla
# Processing Record 31 of Set 6 | erenhot
# Processing Record 32 of Set 6 | kriva palanka
# Processing Record 33 of Set 6 | asosa
# Processing Record 34 of Set 6 | bengkulu
# Processing Record 35 of Set 6 | eyl
# Processing Record 36 of Set 6 | lorengau
# Processing Record 37 of Set 6 | ilo
# Processing Record 38 of Set 6 | along
# Processing Record 39 of Set 6 | balkhash
# Processing Record 40 of Set 6 | tura
# Processing Record 41 of Set 6 | hambantota
# Processing Record 42 of Set 6 | sungaipenuh
# Processing Record 43 of Set 6 | bathsheba
# Processing Record 44 of Set 6 | suntar
# Processing Record 45 of Set 6 | ksenyevka
# City not found. Skipping. . .
# Processing Record 46 of Set 6 | kulu
# Processing Record 47 of Set 6 | san antonio
# Processing Record 48 of Set 6 | tigil
# Processing Record 49 of Set 6 | mayo
# Processing Record 50 of Set 6 | puerto escondido
# Processing Record 1 of Set 7 | raudeberg
# Processing Record 2 of Set 7 | marsh harbour
# Processing Record 3 of Set 7 | codrington
# Processing Record 4 of Set 7 | paamiut
# Processing Record 5 of Set 7 | aswan
# Processing Record 6 of Set 7 | qasigiannguit
# Processing Record 7 of Set 7 | araouane
# Processing Record 8 of Set 7 | minot
# Processing Record 9 of Set 7 | presidencia roque saenz pena
# Processing Record 10 of Set 7 | college
# Processing Record 11 of Set 7 | souillac
# Processing Record 12 of Set 7 | vardo
# Processing Record 13 of Set 7 | nenjiang
# Processing Record 14 of Set 7 | bonavista
# Processing Record 15 of Set 7 | nabire
# Processing Record 16 of Set 7 | constitucion
# Processing Record 17 of Set 7 | merauke
# Processing Record 18 of Set 7 | bikin
# Processing Record 19 of Set 7 | gisborne
# Processing Record 20 of Set 7 | fortuna
# Processing Record 21 of Set 7 | obihiro
# Processing Record 22 of Set 7 | santa cruz
# Processing Record 23 of Set 7 | dicabisagan
# Processing Record 24 of Set 7 | zyryanka
# Processing Record 25 of Set 7 | soyo
# Processing Record 26 of Set 7 | lompoc
# Processing Record 27 of Set 7 | cap malheureux
# Processing Record 28 of Set 7 | zhigansk
# Processing Record 29 of Set 7 | longyearbyen
# Processing Record 30 of Set 7 | dayong
# Processing Record 31 of Set 7 | itarema
# Processing Record 32 of Set 7 | saint matthews
# Processing Record 33 of Set 7 | rio grande
# Processing Record 34 of Set 7 | verkhnevilyuysk
# Processing Record 35 of Set 7 | kandrian
# Processing Record 36 of Set 7 | komsomolskiy
# Processing Record 37 of Set 7 | fort nelson
# Processing Record 38 of Set 7 | hamilton
# Processing Record 39 of Set 7 | hasaki
# Processing Record 40 of Set 7 | alofi
# Processing Record 41 of Set 7 | palmer
# Processing Record 42 of Set 7 | barcelos
# Processing Record 43 of Set 7 | torbay
# Processing Record 44 of Set 7 | havelock
# Processing Record 45 of Set 7 | nerchinskiy zavod
# Processing Record 46 of Set 7 | diamantino
# Processing Record 47 of Set 7 | rocha
# Processing Record 48 of Set 7 | makrana
# Processing Record 49 of Set 7 | saint anthony
# Processing Record 50 of Set 7 | kattivakkam
# Processing Record 1 of Set 8 | neryungri
# Processing Record 2 of Set 8 | saskylakh
# Processing Record 3 of Set 8 | leningradskiy
# Processing Record 4 of Set 8 | palpa
# Processing Record 5 of Set 8 | ambon
# Processing Record 6 of Set 8 | havre-saint-pierre
# Processing Record 7 of Set 8 | puerto cabezas
# Processing Record 8 of Set 8 | schiffdorf
# Processing Record 9 of Set 8 | zhucheng
# Processing Record 10 of Set 8 | mbandaka
# Processing Record 11 of Set 8 | binga
# Processing Record 12 of Set 8 | takestan
# Processing Record 13 of Set 8 | lavrentiya
# Processing Record 14 of Set 8 | moyale
# Processing Record 15 of Set 8 | marabba
# Processing Record 16 of Set 8 | poronaysk
# Processing Record 17 of Set 8 | boo
# Processing Record 18 of Set 8 | kruisfontein
# Processing Record 19 of Set 8 | san patricio
# Processing Record 20 of Set 8 | bull savanna
# Processing Record 21 of Set 8 | abha
# Processing Record 22 of Set 8 | pitimbu
# Processing Record 23 of Set 8 | iqaluit
# Processing Record 24 of Set 8 | namibe
# Processing Record 25 of Set 8 | tarragona
# Processing Record 26 of Set 8 | ginda
# Processing Record 27 of Set 8 | kamenskoye
# City not found. Skipping. . .
# Processing Record 28 of Set 8 | samusu
# City not found. Skipping. . .
# Processing Record 29 of Set 8 | port macquarie
# Processing Record 30 of Set 8 | korla
# Processing Record 31 of Set 8 | portobelo
# Processing Record 32 of Set 8 | carahue
# Processing Record 33 of Set 8 | aflu
# City not found. Skipping. . .
# Processing Record 34 of Set 8 | gaoua
# Processing Record 35 of Set 8 | ancud
# Processing Record 36 of Set 8 | whitehorse
# Processing Record 37 of Set 8 | deputatskiy
# Processing Record 38 of Set 8 | ibotirama
# Processing Record 39 of Set 8 | yurya
# City not found. Skipping. . .
# Processing Record 40 of Set 8 | vanimo
# Processing Record 41 of Set 8 | yomitan
# City not found. Skipping. . .
# Processing Record 42 of Set 8 | kachikau
# City not found. Skipping. . .
# Processing Record 43 of Set 8 | tres coracoes
# Processing Record 44 of Set 8 | victoria
# Processing Record 45 of Set 8 | ixtapa
# Processing Record 46 of Set 8 | tsihombe
# City not found. Skipping. . .
# Processing Record 47 of Set 8 | chapais
# Processing Record 48 of Set 8 | luanda
# Processing Record 49 of Set 8 | yumen
# Processing Record 50 of Set 8 | balotra
# Processing Record 1 of Set 9 | diego de almagro
# Processing Record 2 of Set 9 | humen
# Processing Record 3 of Set 9 | key largo
# Processing Record 4 of Set 9 | waingapu
# Processing Record 5 of Set 9 | ruatoria
# City not found. Skipping. . .
# Processing Record 6 of Set 9 | beyneu
# Processing Record 7 of Set 9 | roald
# Processing Record 8 of Set 9 | keuruu
# Processing Record 9 of Set 9 | airai
# Processing Record 10 of Set 9 | auchel
# Processing Record 11 of Set 9 | labuhan
# Processing Record 12 of Set 9 | akdepe
# Processing Record 13 of Set 9 | jardim
# Processing Record 14 of Set 9 | charleston
# Processing Record 15 of Set 9 | burica
# City not found. Skipping. . .
# Processing Record 16 of Set 9 | alotau
# City not found. Skipping. . .
# Processing Record 17 of Set 9 | karpathos
# Processing Record 18 of Set 9 | bakchar
# Processing Record 19 of Set 9 | dingle
# Processing Record 20 of Set 9 | voykove
# Processing Record 21 of Set 9 | nagornskiy
# Processing Record 22 of Set 9 | kudahuvadhoo
# Processing Record 23 of Set 9 | ketchikan
# Processing Record 24 of Set 9 | shingu
# Processing Record 25 of Set 9 | taoudenni
# Processing Record 26 of Set 9 | klaksvik
# Processing Record 27 of Set 9 | ekhabi
# Processing Record 28 of Set 9 | celestun
# Processing Record 29 of Set 9 | pinawa
# Processing Record 30 of Set 9 | rapid valley
# Processing Record 31 of Set 9 | mao
# Processing Record 32 of Set 9 | buchanan
# Processing Record 33 of Set 9 | teguldet
# Processing Record 34 of Set 9 | honiara
# Processing Record 35 of Set 9 | takoradi
# Processing Record 36 of Set 9 | golyshmanovo
# Processing Record 37 of Set 9 | sidi ali
# Processing Record 38 of Set 9 | chkalovskoye
# Processing Record 39 of Set 9 | goundam
# Processing Record 40 of Set 9 | porto velho
# Processing Record 41 of Set 9 | gemena
# Processing Record 42 of Set 9 | crab hill
# City not found. Skipping. . .
# Processing Record 43 of Set 9 | blackwater
# Processing Record 44 of Set 9 | cravo norte
# Processing Record 45 of Set 9 | arvi
# Processing Record 46 of Set 9 | sorong
# Processing Record 47 of Set 9 | salalah
# Processing Record 48 of Set 9 | shache
# Processing Record 49 of Set 9 | umm kaddadah
# Processing Record 50 of Set 9 | karachi
# Processing Record 1 of Set 10 | ayan
# Processing Record 2 of Set 10 | otyniya
# Processing Record 3 of Set 10 | ponta do sol
# Processing Record 4 of Set 10 | doctor pedro p. pena
# City not found. Skipping. . .
# Processing Record 5 of Set 10 | oxford
# Processing Record 6 of Set 10 | gasa
# Processing Record 7 of Set 10 | penza
# Processing Record 8 of Set 10 | ust-tsilma
# Processing Record 9 of Set 10 | karratha
# Processing Record 10 of Set 10 | thunder bay
# Processing Record 11 of Set 10 | formoso do araguaia
# City not found. Skipping. . .
# Processing Record 12 of Set 10 | egvekinot
# Processing Record 13 of Set 10 | laguna de perlas
# Processing Record 14 of Set 10 | rey bouba
# Processing Record 15 of Set 10 | moussoro
# Processing Record 16 of Set 10 | banda aceh
# Processing Record 17 of Set 10 | achinsk
# Processing Record 18 of Set 10 | kalabo
# Processing Record 19 of Set 10 | rustenburg
# Processing Record 20 of Set 10 | corn island
# Processing Record 21 of Set 10 | meyungs
# City not found. Skipping. . .
# Processing Record 22 of Set 10 | aksay
# Processing Record 23 of Set 10 | daoukro
# Processing Record 24 of Set 10 | kamsack
# Processing Record 25 of Set 10 | baramati
# Processing Record 26 of Set 10 | banfora
# Processing Record 27 of Set 10 | carolina
# Processing Record 28 of Set 10 | mangan
# Processing Record 29 of Set 10 | general pico
# Processing Record 30 of Set 10 | ewa beach
# Processing Record 31 of Set 10 | olavarria
# Processing Record 32 of Set 10 | sauk rapids
# Processing Record 33 of Set 10 | conde
# Processing Record 34 of Set 10 | dolbeau
# City not found. Skipping. . .
# Processing Record 35 of Set 10 | port lincoln
# Processing Record 36 of Set 10 | keelung
# Processing Record 37 of Set 10 | of
# City not found. Skipping. . .
# Processing Record 38 of Set 10 | midland
# Processing Record 39 of Set 10 | noshiro
# Processing Record 40 of Set 10 | leeton
# Processing Record 41 of Set 10 | utiroa
# City not found. Skipping. . .
# Processing Record 42 of Set 10 | navoi
# Processing Record 43 of Set 10 | moose factory
# Processing Record 44 of Set 10 | hauge
# Processing Record 45 of Set 10 | mount isa
# Processing Record 46 of Set 10 | peniche
# Processing Record 47 of Set 10 | saleaula
# City not found. Skipping. . .
# Processing Record 48 of Set 10 | richards bay
# Processing Record 49 of Set 10 | bethanien
# Processing Record 50 of Set 10 | vizinga
# Processing Record 1 of Set 11 | lasa
# Processing Record 2 of Set 11 | mumbwa
# Processing Record 3 of Set 11 | vao
# Processing Record 4 of Set 11 | usevya
# Processing Record 5 of Set 11 | vicosa
# Processing Record 6 of Set 11 | coihaique
# Processing Record 7 of Set 11 | goderich
# Processing Record 8 of Set 11 | burns lake
# Processing Record 9 of Set 11 | madang
# Processing Record 10 of Set 11 | vaitape
# Processing Record 11 of Set 11 | rizhao
# Processing Record 12 of Set 11 | puerto del rosario
# Processing Record 13 of Set 11 | lekoni
# Processing Record 14 of Set 11 | amga
# Processing Record 15 of Set 11 | padang
# Processing Record 16 of Set 11 | novomikhaylovskiy
# Processing Record 17 of Set 11 | lampang
# Processing Record 18 of Set 11 | vostok
# Processing Record 19 of Set 11 | sayyan
# Processing Record 20 of Set 11 | suruc
# Processing Record 21 of Set 11 | graaff-reinet
# Processing Record 22 of Set 11 | faanui
# Processing Record 23 of Set 11 | kerouane
# Processing Record 24 of Set 11 | dombarovskiy
# Processing Record 25 of Set 11 | onega
# Processing Record 26 of Set 11 | qurayyat
# Processing Record 27 of Set 11 | golspie
# Processing Record 28 of Set 11 | bilibino
# Processing Record 29 of Set 11 | duvan
# Processing Record 30 of Set 11 | raton
# Processing Record 31 of Set 11 | wajima
# Processing Record 32 of Set 11 | mayumba
# Processing Record 33 of Set 11 | brae
# Processing Record 34 of Set 11 | porto novo
# Processing Record 35 of Set 11 | oswego
# Processing Record 36 of Set 11 | riyaq
# City not found. Skipping. . .
# Processing Record 37 of Set 11 | sobolevo
# Processing Record 38 of Set 11 | christchurch
# Processing Record 39 of Set 11 | cabra
# Processing Record 40 of Set 11 | shelburne
# Processing Record 41 of Set 11 | palauig
# Processing Record 42 of Set 11 | claremont
# Processing Record 43 of Set 11 | jujuy
# City not found. Skipping. . .
# Processing Record 44 of Set 11 | paris
# Processing Record 45 of Set 11 | tiznit
# Processing Record 46 of Set 11 | hanstholm
# Processing Record 47 of Set 11 | atikokan
# Processing Record 48 of Set 11 | emilio carranza
# Processing Record 49 of Set 11 | san jose de guanipa
# Processing Record 50 of Set 11 | acapulco
# Processing Record 1 of Set 12 | smithers
# Processing Record 2 of Set 12 | corning
# Processing Record 3 of Set 12 | usinsk
# Processing Record 4 of Set 12 | chernyshevskiy
# Processing Record 5 of Set 12 | hirara
# Processing Record 6 of Set 12 | tabuk
# Processing Record 7 of Set 12 | nanortalik
# Processing Record 8 of Set 12 | arlit
# Processing Record 9 of Set 12 | pulaski
# Processing Record 10 of Set 12 | cockburn town
# Processing Record 11 of Set 12 | halifax
# Processing Record 12 of Set 12 | okhotsk
# Processing Record 13 of Set 12 | mugumu
# Processing Record 14 of Set 12 | jawhar
# Processing Record 15 of Set 12 | novikovo
# Processing Record 16 of Set 12 | myrtle grove
# Processing Record 17 of Set 12 | goba
# Processing Record 18 of Set 12 | bahia honda
# Processing Record 19 of Set 12 | lakes entrance
# Processing Record 20 of Set 12 | muriwai beach
# Processing Record 21 of Set 12 | sarakhs
# Processing Record 22 of Set 12 | bonthe
# Processing Record 23 of Set 12 | praya
# Processing Record 24 of Set 12 | pelym
# Processing Record 25 of Set 12 | lingao
# Processing Record 26 of Set 12 | contamana
# Processing Record 27 of Set 12 | talnakh
# Processing Record 28 of Set 12 | yatou
# Processing Record 29 of Set 12 | changji
# Processing Record 30 of Set 12 | lufilufi
# Processing Record 31 of Set 12 | tumannyy
# City not found. Skipping. . .
# Processing Record 32 of Set 12 | abu samrah
# Processing Record 33 of Set 12 | lolua
# City not found. Skipping. . .
# Processing Record 34 of Set 12 | panzhihua
# Processing Record 35 of Set 12 | zhigalovo
# Processing Record 36 of Set 12 | khudumelapye
# Processing Record 37 of Set 12 | kimbe
# Processing Record 38 of Set 12 | tulum
# Processing Record 39 of Set 12 | rincon
# Processing Record 40 of Set 12 | tungor
# Processing Record 41 of Set 12 | saint-pierre
# Processing Record 42 of Set 12 | ust-ishim
# Processing Record 43 of Set 12 | cayenne
# Processing Record 44 of Set 12 | tromso
# Processing Record 45 of Set 12 | chagda
# City not found. Skipping. . .
# Processing Record 46 of Set 12 | tucuma
# Processing Record 47 of Set 12 | touros
# Processing Record 48 of Set 12 | memmingen
# Processing Record 49 of Set 12 | nalchiti
# Processing Record 50 of Set 12 | fare
# Processing Record 1 of Set 13 | limbang
# Processing Record 2 of Set 13 | damaturu
# Processing Record 3 of Set 13 | esqueda
# Processing Record 4 of Set 13 | bam
# Processing Record 5 of Set 13 | ploemeur
# Processing Record 6 of Set 13 | cartagena del chaira
# Processing Record 7 of Set 13 | north myrtle beach
# Processing Record 8 of Set 13 | campo maior
# Processing Record 9 of Set 13 | yerofey pavlovich
# Processing Record 10 of Set 13 | sao gabriel da cachoeira
# Processing Record 11 of Set 13 | lao cai
# Processing Record 12 of Set 13 | tautira
# Processing Record 13 of Set 13 | lixourion
# Processing Record 14 of Set 13 | peresichna
# Processing Record 15 of Set 13 | gorontalo
# Processing Record 16 of Set 13 | belyy yar
# Processing Record 17 of Set 13 | taburi
# City not found. Skipping. . .
# Processing Record 18 of Set 13 | tiarei
# Processing Record 19 of Set 13 | sovetskiy
# Processing Record 20 of Set 13 | mandera
# Processing Record 21 of Set 13 | kerki
# City not found. Skipping. . .
# Processing Record 22 of Set 13 | boma
# Processing Record 23 of Set 13 | sivas
# Processing Record 24 of Set 13 | ibra
# Processing Record 25 of Set 13 | davidson
# Processing Record 26 of Set 13 | yandoon
# City not found. Skipping. . .
# Processing Record 27 of Set 13 | salekhard
# Processing Record 28 of Set 13 | moron
# Processing Record 29 of Set 13 | khani
# Processing Record 30 of Set 13 | nara
# Processing Record 31 of Set 13 | huarmey
# Processing Record 32 of Set 13 | oistins
# Processing Record 33 of Set 13 | flinders
# Processing Record 34 of Set 13 | carballo
# Processing Record 35 of Set 13 | iquitos
# Processing Record 36 of Set 13 | mandalgovi
# Processing Record 37 of Set 13 | colares
# Processing Record 38 of Set 13 | salto
# Processing Record 39 of Set 13 | coxim
# Processing Record 40 of Set 13 | suleja
# Processing Record 41 of Set 13 | abalak
# Processing Record 42 of Set 13 | gamba
# Processing Record 43 of Set 13 | amuntai
# Processing Record 44 of Set 13 | miraflores
# Processing Record 45 of Set 13 | tuscaloosa
# Processing Record 46 of Set 13 | beloha
# Processing Record 47 of Set 13 | yanan
# City not found. Skipping. . .
# Processing Record 48 of Set 13 | tual
# Processing Record 49 of Set 13 | jabiru
# City not found. Skipping. . .
# Processing Record 50 of Set 13 | santa marta
# Processing Record 1 of Set 14 | ozark
# Processing Record 2 of Set 14 | tanshui
# City not found. Skipping. . .
# Processing Record 3 of Set 14 | alanya
# Processing Record 4 of Set 14 | analipsis
# Processing Record 5 of Set 14 | george town
# Processing Record 6 of Set 14 | agen
# Processing Record 7 of Set 14 | sarh
# Processing Record 8 of Set 14 | zabaykalsk
# Processing Record 9 of Set 14 | reconquista
# Processing Record 10 of Set 14 | maarianhamina
# Processing Record 11 of Set 14 | pueblo
# Processing Record 12 of Set 14 | findlay
# Processing Record 13 of Set 14 | deh rawud
# City not found. Skipping. . .
# Processing Record 14 of Set 14 | mahibadhoo
# Processing Record 15 of Set 14 | apastovo
# Processing Record 16 of Set 14 | vilhena
# Processing Record 17 of Set 14 | tateyama
# Processing Record 18 of Set 14 | trojes
# Processing Record 19 of Set 14 | viligili
# City not found. Skipping. . .
# Processing Record 20 of Set 14 | belyy
# Processing Record 21 of Set 14 | aktau
# Processing Record 22 of Set 14 | kijang
# Processing Record 23 of Set 14 | pangnirtung
# Processing Record 24 of Set 14 | thinadhoo
# Processing Record 25 of Set 14 | sabha
# Processing Record 26 of Set 14 | san cristobal
# Processing Record 27 of Set 14 | ukiah
# Processing Record 28 of Set 14 | tombouctou
# Processing Record 29 of Set 14 | santa isabel do rio negro
# Processing Record 30 of Set 14 | ngukurr
# City not found. Skipping. . .
# Processing Record 31 of Set 14 | simbahan
# Processing Record 32 of Set 14 | ambilobe
# Processing Record 33 of Set 14 | esmeraldas
# Processing Record 34 of Set 14 | jambi
# Processing Record 35 of Set 14 | bontang
# Processing Record 36 of Set 14 | le vauclin
# Processing Record 37 of Set 14 | tsiroanomandidy
# Processing Record 38 of Set 14 | ariquemes
# Processing Record 39 of Set 14 | rosarito
# Processing Record 40 of Set 14 | huazolotitlan
# City not found. Skipping. . .
# Processing Record 41 of Set 14 | broken hill
# Processing Record 42 of Set 14 | tayibe
# City not found. Skipping. . .
# Processing Record 43 of Set 14 | necochea
# Processing Record 44 of Set 14 | milicz
# Processing Record 45 of Set 14 | bolonchen
# City not found. Skipping. . .
# Processing Record 46 of Set 14 | otavi
# Processing Record 47 of Set 14 | port moresby
# Processing Record 48 of Set 14 | sakakah
# Processing Record 49 of Set 14 | tara
# Processing Record 50 of Set 14 | khonuu
# City not found. Skipping. . .
# Processing Record 1 of Set 15 | mys shmidta
# City not found. Skipping. . .
# Processing Record 2 of Set 15 | bezhetsk
# Processing Record 3 of Set 15 | sisimiut
# Processing Record 4 of Set 15 | gat
# Processing Record 5 of Set 15 | agadez
# Processing Record 6 of Set 15 | kyra
# Processing Record 7 of Set 15 | plettenberg bay
# Processing Record 8 of Set 15 | mouila
# Processing Record 9 of Set 15 | darlington
# Processing Record 10 of Set 15 | peterhead
# Processing Record 11 of Set 15 | ferrol
# Processing Record 12 of Set 15 | bjerkvik
# Processing Record 13 of Set 15 | jiayuguan
# Processing Record 14 of Set 15 | yuzhno-yeniseyskiy
# City not found. Skipping. . .
# Processing Record 15 of Set 15 | ahtopol
# Processing Record 16 of Set 15 | sumenep
# Processing Record 17 of Set 15 | kondinskoye
# Processing Record 18 of Set 15 | high level
# Processing Record 19 of Set 15 | miranorte
# City not found. Skipping. . .
# Processing Record 20 of Set 15 | marawi
# Processing Record 21 of Set 15 | san carlos de bariloche
# Processing Record 22 of Set 15 | todos santos
# Processing Record 23 of Set 15 | rungata
# City not found. Skipping. . .
# Processing Record 24 of Set 15 | auki
# Processing Record 25 of Set 15 | denpasar
# Processing Record 26 of Set 15 | cardiff
# Processing Record 27 of Set 15 | naugarzan
# City not found. Skipping. . .
# Processing Record 28 of Set 15 | geertruidenberg
# Processing Record 29 of Set 15 | ulaanbaatar
# Processing Record 30 of Set 15 | houston
# Processing Record 31 of Set 15 | halalo
# City not found. Skipping. . .
# Processing Record 32 of Set 15 | tsabong
# Processing Record 33 of Set 15 | pokhara
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Yar-Sale  66.8333   70.8333     34.11        90          97
# 1        Kozhva  65.1073   57.0459     36.52        72          99
# 2         Basco  20.4487  121.9702     80.69        74          90
# 3          Laje -10.1833  -40.9667     91.81        21          96
# 4      Dubasari  47.2631   29.1608     49.30        63          96
# 5         Muros  42.7762   -9.0603     66.83        91          26
# 6    Port Hardy  50.6996 -127.4199     48.27        71         100
# 7     Chalmette  29.9427  -89.9634     76.08        58         100
# 8         Bluff -46.6000  168.3333     46.58        71         100
# 9  Punta Arenas -53.1500  -70.9167     47.91        67          81
#
#    Wind Speed       Description Country                 Date
# 0       11.16   overcast clouds      RU  2021-10-18 20:02:45
# 1       10.13   overcast clouds      RU  2021-10-18 20:02:45
# 2       17.49   overcast clouds      PH  2021-10-18 20:02:46
# 3        9.51   overcast clouds      BR  2021-10-18 20:02:46
# 4        6.85   overcast clouds      MD  2021-10-18 20:02:47
# 5        6.49  scattered clouds      ES  2021-10-18 20:02:47
# 6        8.50   overcast clouds      CA  2021-10-18 20:02:47
# 7        1.99   overcast clouds      US  2021-10-18 20:00:46
# 8       19.26   overcast clouds      NZ  2021-10-18 20:01:10
# 9       20.22     broken clouds      CL  2021-10-18 20:02:48

# %%
new_column_order = ['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Description']
city_data_df = city_data_df[new_column_order]

# %%
city_data_df.head()
# Out:
#        City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Yar-Sale      RU  66.8333   70.8333     34.11        90          97
# 1    Kozhva      RU  65.1073   57.0459     36.52        72          99
# 2     Basco      PH  20.4487  121.9702     80.69        74          90
# 3      Laje      BR -10.1833  -40.9667     91.81        21          96
# 4  Dubasari      MD  47.2631   29.1608     49.30        63          96
#
#    Wind Speed      Description
# 0       11.16  overcast clouds
# 1       10.13  overcast clouds
# 2       17.49  overcast clouds
# 3        9.51  overcast clouds
# 4        6.85  overcast clouds

# %%
# create the output file (CSV)
output_data_file = "WeatherPy_Database.csv"

# export the city_data into a .csv
city_data_df.to_csv(output_data_file, index_label="City_ID")
